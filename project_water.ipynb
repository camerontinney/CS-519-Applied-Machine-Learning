# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
import seaborn as sns

# %%
# water dataset practice for project
water = pd.read_csv('water_potability.csv')
# water.head(10)
water.tail()
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225              NaN   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1

# %%
# stage 3:
# collect large datasets
# do analysis for the data: statistics about the data, plotting information
water.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# min      181.483754        2.200000         0.738000     1.450000     0.000000
# 25%      365.734414       12.065801        55.844536     3.439711     0.000000
# 50%      421.884968       14.218338        66.622485     3.955028     0.000000
# 75%      481.792304       16.557652        77.337473     4.500320     1.000000
# max      753.342620       28.300000       124.000000     6.739000     1.000000

# %%
len(water)
# Out:
# 3276

# %%
water.index
# Out:
# RangeIndex(start=0, stop=3276, step=1)

# %%
water.shape
# Out:
# (3276, 10)

# %%
water.count()
# Out:
# ph                 2785
# Hardness           3276
# Solids             3276
# Chloramines        3276
# Sulfate            2495
# Conductivity       3276
# Organic_carbon     3276
# Trihalomethanes    3114
# Turbidity          3276
# Potability         3276
# dtype: int64

# %%
water.sample(5)
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 2455        NaN  176.413638  12674.672773     8.988477  354.768115
# 2320   7.243410  188.046296  20877.534841     8.454107         NaN
# 582    8.576740  221.150258  24897.286602     6.222626  341.809210
# 795   10.268415  225.074218  14694.420625     6.722843  300.763772
# 1866   6.922652  185.818989  14682.665838     9.886831  341.066404
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 2455    344.420435       12.682869        83.567356   4.403877           1
# 2320    377.649344       16.357375        71.627136   4.466936           1
# 582     389.292785       15.952132        36.082583   3.916115           0
# 795     353.630913       13.553796        64.012944   5.199865           1
# 1866    560.787703       22.466128        64.395422   2.877354           0

# %%
water['ph']
# Out:
# 0            NaN
# 1       3.716080
# 2       8.099124
# 3       8.316766
# 4       9.092223
#           ...
# 3271    4.668102
# 3272    7.808856
# 3273    9.419510
# 3274    5.126763
# 3275    7.874671
# Name: ph, Length: 3276, dtype: float64

# %%
water.nunique()
# Out:
# ph                 2785
# Hardness           3276
# Solids             3276
# Chloramines        3276
# Sulfate            2495
# Conductivity       3276
# Organic_carbon     3276
# Trihalomethanes    3114
# Turbidity          3276
# Potability            2
# dtype: int64

# %%
water.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
# replace NaN values with mean
# imp = SimpleImputer(missing_values=np.nan, strategy='mean')
# imp = imp.fit(water.values)
# new_water = imp.transform(water.values)
# new_water

# %%
# replace NaN values with mean
new_water = water.fillna(water.mean())
new_water
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0     7.080795  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246  333.775777
# 2     8.099124  224.236259  19909.541732     9.275884  333.775777
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  333.775777
# 3273  9.419510  175.762646  33155.578218     7.350233  333.775777
# 3274  5.126763  230.603758  11983.869376     6.303357  333.775777
# 3275  7.874671  195.102299  17404.177061     7.509306  333.775777
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# 1       592.885359       15.180013        56.329076   4.500656           0
# 2       418.606213       16.868637        66.420093   3.055934           0
# 3       363.266516       18.436524       100.341674   4.628771           0
# 4       398.410813       11.558279        31.997993   4.075075           0
# ...            ...             ...              ...        ...         ...
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225        66.396293   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1
#
# [3276 rows x 10 columns]

# %%
# print a random sample
new_water.sample(5)
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 3185  6.110022  234.800957  16663.539074     5.984536  348.055211
# 1053  8.922410  207.520726  13291.922609     8.560537  357.944327
# 362   6.876451  190.844514  21979.031671     5.630558  363.831706
# 753   7.694265  184.836301  22673.034472     5.701063  333.775777
# 1854  5.964065  241.030899  22168.331561     6.208118  333.775777
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 3185    437.892115       10.059523        66.396293   2.817780           1
# 1053    468.538326       15.692738       107.282329   4.081728           0
# 362     349.186085        9.551732        68.410851   4.545341           1
# 753     439.633027        8.857706        64.975574   5.707193           1
# 1854    486.516884       13.172989        64.719240   4.696721           0

# %%
new_water.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  3276.000000  3276.000000   3276.000000  3276.000000  3276.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.469956    32.879761   8768.570828     1.583085    36.142612
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.277673   176.850538  15666.690297     6.127421   317.094638
# 50%       7.080795   196.967627  20927.833607     7.130299   333.775777
# 75%       7.870050   216.667456  27332.762127     8.114887   350.385756
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3276.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        15.769881     0.780382     0.487849
# min      181.483754        2.200000         0.738000     1.450000     0.000000
# 25%      365.734414       12.065801        56.647656     3.439711     0.000000
# 50%      421.884968       14.218338        66.396293     3.955028     0.000000
# 75%      481.792304       16.557652        76.666609     4.500320     1.000000
# max      753.342620       28.300000       124.000000     6.739000     1.000000

# %%
# water[['Sulfate', 'Hardness', 'Conductivity']].plot.box(grid=True)

# %%
# correlation matrix
corr_mat = new_water[['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
                      'Organic_carbon', 'Trihalomethanes','Turbidity']].corr()
corr_mat.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# /var/folders/rn/ypkjb02566v9wcn1cq48khmc0000gq/T/ipykernel_75402/3232442200.py:4: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr_mat.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_449fd_row0_col0, #T_449fd_row1_col1, #T_449fd_row2_col2, #T_449fd_row3_col3, #T_449fd_row4_col4, #T_449fd_row5_col5, #T_449fd_row6_col6, #T_449fd_row7_col7, #T_449fd_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_449fd_row0_col1, #T_449fd_row6_col4 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_449fd_row0_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_449fd_row0_col3, #T_449fd_row1_col3, #T_449fd_row2_col5, #T_449fd_row2_col6, #T_449fd_row3_col8 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_449fd_row0_col4, #T_449fd_row5_col2 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_449fd_row0_col5, #T_449fd_row2_col1, #T_449fd_row3_col7, #T_449fd_row5_col8, #T_449fd_row8_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_449fd_row0_col6, #T_449fd_row5_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_449fd_row0_col7, #T_449fd_row1_col6, #T_449fd_row8_col5 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_449fd_row0_col8, #T_449fd_row1_col5, #T_449fd_row2_col0, #T_449fd_row2_col3, #T_449fd_row2_col4, #T_449fd_row3_col5, #T_449fd_row4_col1, #T_449fd_row4_col2, #T_449fd_row4_col7, #T_449fd_row8_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_449fd_row1_col0, #T_449fd_row8_col2 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_449fd_row1_col2, #T_449fd_row4_col0, #T_449fd_row4_col3, #T_449fd_row6_col1 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_449fd_row1_col4, #T_449fd_row5_col6 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_449fd_row1_col7, #T_449fd_row3_col6, #T_449fd_row6_col7, #T_449fd_row7_col6, #T_449fd_row7_col8 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_449fd_row1_col8 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_449fd_row2_col7 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_449fd_row2_col8, #T_449fd_row4_col6, #T_449fd_row6_col3 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_449fd_row3_col0, #T_449fd_row5_col3, #T_449fd_row6_col5 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_449fd_row3_col1 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_449fd_row3_col2, #T_449fd_row8_col3 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_449fd_row3_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_449fd_row4_col5, #T_449fd_row6_col8 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_449fd_row4_col8, #T_449fd_row5_col7, #T_449fd_row7_col5 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_449fd_row5_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_449fd_row5_col4 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_449fd_row6_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_449fd_row6_col2 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_449fd_row7_col0, #T_449fd_row7_col3 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_449fd_row7_col1, #T_449fd_row8_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_449fd_row7_col2, #T_449fd_row8_col4 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_449fd_row7_col4 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_449fd_row8_col7 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_449fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_449fd_level0_col0" class="col_heading level0 col0" >ph</th>
#       <th id="T_449fd_level0_col1" class="col_heading level0 col1" >Hardness</th>
#       <th id="T_449fd_level0_col2" class="col_heading level0 col2" >Solids</th>
#       <th id="T_449fd_level0_col3" class="col_heading level0 col3" >Chloramines</th>
#       <th id="T_449fd_level0_col4" class="col_heading level0 col4" >Sulfate</th>
#       <th id="T_449fd_level0_col5" class="col_heading level0 col5" >Conductivity</th>
#       <th id="T_449fd_level0_col6" class="col_heading level0 col6" >Organic_carbon</th>
#       <th id="T_449fd_level0_col7" class="col_heading level0 col7" >Trihalomethanes</th>
#       <th id="T_449fd_level0_col8" class="col_heading level0 col8" >Turbidity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_449fd_level0_row0" class="row_heading level0 row0" >ph</th>
#       <td id="T_449fd_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_449fd_row0_col1" class="data row0 col1" >0.08</td>
#       <td id="T_449fd_row0_col2" class="data row0 col2" >-0.08</td>
#       <td id="T_449fd_row0_col3" class="data row0 col3" >-0.03</td>
#       <td id="T_449fd_row0_col4" class="data row0 col4" >0.01</td>
#       <td id="T_449fd_row0_col5" class="data row0 col5" >0.02</td>
#       <td id="T_449fd_row0_col6" class="data row0 col6" >0.04</td>
#       <td id="T_449fd_row0_col7" class="data row0 col7" >0.00</td>
#       <td id="T_449fd_row0_col8" class="data row0 col8" >-0.04</td>
#     </tr>
#     <tr>
#       <th id="T_449fd_level0_row1" class="row_heading level0 row1" >Hardness</th>
#       <td id="T_449fd_row1_col0" class="data row1 col0" >0.08</td>
#       <td id="T_449fd_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_449fd_row1_col2" class="data row1 col2" >-0.05</td>
#       <td id="T_449fd_row1_col3" class="data row1 col3" >-0.03</td>
#       <td id="T_449fd_row1_col4" class="data row1 col4" >-0.09</td>
#       <td id="T_449fd_row1_col5" class="data row1 col5" >-0.02</td>
#       <td id="T_449fd_row1_col6" class="data row1 col6" >0.00</td>
#       <td id="T_449fd_row1_col7" class="data row1 col7" >-0.01</td>
#       <td id="T_449fd_row1_col8" class="data row1 col8" >-0.01</td>
#     </tr>
#     <tr>
#       <th id="T_449fd_level0_row2" class="row_heading level0 row2" >Solids</th>
#       <td id="T_449fd_row2_col0" class="data row2 col0" >-0.08</td>
#       <td id="T_449fd_row2_col1" class="data row2 col1" >-0.05</td>
#       <td id="T_449fd_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_449fd_row2_col3" class="data row2 col3" >-0.07</td>
#       <td id="T_449fd_row2_col4" class="data row2 col4" >-0.15</td>
#       <td id="T_449fd_row2_col5" class="data row2 col5" >0.01</td>
#       <td id="T_449fd_row2_col6" class="data row2 col6" >0.01</td>
#       <td id="T_449fd_row2_col7" class="data row2 col7" >-0.01</td>
#       <td id="T_449fd_row2_col8" class="data row2 col8" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_449fd_level0_row3" class="row_heading level0 row3" >Chloramines</th>
#       <td id="T_449fd_row3_col0" class="data row3 col0" >-0.03</td>
#       <td id="T_449fd_row3_col1" class="data row3 col1" >-0.03</td>
#       <td id="T_449fd_row3_col2" class="data row3 col2" >-0.07</td>
#       <td id="T_449fd_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_449fd_row3_col4" class="data row3 col4" >0.02</td>
#       <td id="T_449fd_row3_col5" class="data row3 col5" >-0.02</td>
#       <td id="T_449fd_row3_col6" class="data row3 col6" >-0.01</td>
#       <td id="T_449fd_row3_col7" class="data row3 col7" >0.02</td>
#       <td id="T_449fd_row3_col8" class="data row3 col8" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_449fd_level0_row4" class="row_heading level0 row4" >Sulfate</th>
#       <td id="T_449fd_row4_col0" class="data row4 col0" >0.01</td>
#       <td id="T_449fd_row4_col1" class="data row4 col1" >-0.09</td>
#       <td id="T_449fd_row4_col2" class="data row4 col2" >-0.15</td>
#       <td id="T_449fd_row4_col3" class="data row4 col3" >0.02</td>
#       <td id="T_449fd_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_449fd_row4_col5" class="data row4 col5" >-0.01</td>
#       <td id="T_449fd_row4_col6" class="data row4 col6" >0.03</td>
#       <td id="T_449fd_row4_col7" class="data row4 col7" >-0.03</td>
#       <td id="T_449fd_row4_col8" class="data row4 col8" >-0.01</td>
#     </tr>
#     <tr>
#       <th id="T_449fd_level0_row5" class="row_heading level0 row5" >Conductivity</th>
#       <td id="T_449fd_row5_col0" class="data row5 col0" >0.02</td>
#       <td id="T_449fd_row5_col1" class="data row5 col1" >-0.02</td>
#       <td id="T_449fd_row5_col2" class="data row5 col2" >0.01</td>
#       <td id="T_449fd_row5_col3" class="data row5 col3" >-0.02</td>
#       <td id="T_449fd_row5_co

# %%
# new_water.hist(grid=False, edgecolor='black')

# %%
new_water.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
new_water.isna().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
sns.countplot(data=new_water, x='Potability')
plt.title('Potable water proportions')
# Out:
# Text(0.5, 1.0, 'Potable water proportions')

# %%
# histogram of the distribution of each feature in dataset

features = ['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity', 'Organic_carbon',
            'Trihalomethanes','Turbidity']
plt.figure(figsize=(20, 20))
plot_data = new_water.drop('Potability', axis=1)
for i in enumerate(features):
    plt.subplot(3, 3, i[0]+1)
    sns.histplot(
    data=plot_data,
    x=plot_data[i[1]],
    hue=new_water['Potability'],
    palette=['green', 'blue'],
    kde=True,
    multiple='stack',
    alpha=0.4)
    plt.xticks(rotation=25)

# %%
plt.figure(figsize=(10,10))
new_water.boxplot(column='ph', by='Potability', grid=True)
# plt.title('Comparison of Ph and Potability')
plt.show()

# %%
plt.figure(figsize=(10,10))
new_water.boxplot(column='Hardness', by='Potability', grid=True)
plt.show()

# %%
plt.figure(figsize=(10,10))
new_water.boxplot(column='Solids', by='Potability', grid=True)
plt.show()

# %%
plt.figure(figsize=(10,10))
new_water.boxplot(column='Chloramines', by='Potability', grid=True)
plt.show()

# %%
plt.figure(figsize=(10,10))
new_water.boxplot(column='Sulfate', by='Potability', grid=True)
plt.show()

# %%
plt.figure(figsize=(10,10))
new_water.boxplot(column='Conductivity', by='Potability', grid=True)
plt.show()

# %%
plt.figure(figsize=(10,10))
new_water.boxplot(column='Organic_carbon', by='Potability', grid=True)
plt.show()

# %%
plt.figure(figsize=(10,10))
new_water.boxplot(column='Trihalomethanes', by='Potability', grid=True)
plt.show()

# %%
plt.figure(figsize=(10,10))
new_water.boxplot(column='Turbidity', by='Potability', grid=True)
plt.show()
